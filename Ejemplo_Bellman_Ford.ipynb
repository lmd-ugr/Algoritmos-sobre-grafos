# %%
from Bellman_Ford import *

# %%
g=Grafo()
g.añadir_arista(1,2)
g.añadir_arista(3,2)
g.añadir_arista(3,4)
g.añadir_arista(1,4)
g.añadir_arista(1,3)
g.ponderado([10,5,10,8,4])
g.dibujar_ponderado('circo')

# %%
for i in g.vertices:
    print('Vértice inicial: ' , i, '\n')
    print(Bellman_Ford(g, i))
    print('\n')
# Out:
# Vértice inicial:  1
#
# [0, 10, 4, 8]
# [0, 9, 4, 8]
# [0, 9, 4, 8]
# [[0, 9, 4, 8], [1, 3, 3, 4]]
#
#
# Vértice inicial:  2
#
# [10, 0, 5, inf]
# [9, 0, 5, 15]
# [9, 0, 5, 15]
# [[9, 0, 5, 15], [3, 2, 3, 3]]
#
#
# Vértice inicial:  3
#
# [4, 5, 0, 10]
# [4, 5, 0, 10]
# [[4, 5, 0, 10], [1, 2, 3, 4]]
#
#
# Vértice inicial:  4
#
# [8, inf, 10, 0]
# [8, 15, 10, 0]
# [8, 15, 10, 0]
# [[8, 15, 10, 0], [1, 3, 3, 4]]
