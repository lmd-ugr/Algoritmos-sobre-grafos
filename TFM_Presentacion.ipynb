# %% [markdown]
# ## Fleury

# %%
from Fleury import *

# %%
g=Grafo([],[(1,2),(2,3),(3,4),(4,1),(2,4),(2,5),(4,5)])
g.dibujar('circo')

# %%
Fleury(g)
# Out:
# [2, 1, 4, 3, 2, 4]

# %%
Fleury(g,True)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Hierholzer

# %%
from Hierholzer import *

# %%
Hierholzer(g)
# Out:
# [4, 3, 2, 1, 4, 2]

# %%
Hierholzer(g,True)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Kauffman-Malgrange

# %%
g=Grafo([],[(1,2), (2,3), (2,4), (3,4), (3,5), (4,5), (5,6)])
g.dibujar('neato')

# %%
from Kauffman_Malgrange import *

# %%
Kauffman_Malgrange(g, True)
# Out:
# A Jupyter Widget

# %%
Kauffman_Malgrange(g)
# Out:
# [[(1, 2, 4, 3, 5, 6), (1, 2, 3, 4, 5, 6)],
#  [(6, 5, 4, 3, 2, 1), (6, 5, 3, 4, 2, 1)]]

# %% [markdown]
# ## Secuencias gráficas

# %%
from grafos import *

# %%
g=Grafo()
g.Secuencia_a_Grafo([5,3,2,2,2,2], True)
# Out:
# La secuencia es grAfica
# A Jupyter Widget

# %%
g.dibujar('neato') # El método nos dice si la secuencia es gráfica y nos devuelve su realización

# %% [markdown]
# ## Polinomio cormático

# %%
from grafos import *

# %%
g=Grafo([], [(1,2), (1,3), (2,3)])
g.dibujar('circo')

# %%
g.Polinomio_Cromatico(3)
# Out:
# 6

# %% [markdown]
# ## Código Prüfer

# %%
from Prufer import *

# %%
g=Grafo([], [(1,2), (2,1)])
g.dibujar()

# %%
g.Prufer()
# Out:
# (ValueError, 'El grafo no es un árbol.')

# %%
g=Grafo([],[(1,2), (2,3), (2,4), (4,5), (4,6)])
g.dibujar()

# %%
g.Prufer()
# Out:
# [2, 2, 4, 4]

# %%
Prufer_a_Arbol([2,2,4,4]).dibujar()

# %%
Prufer_a_Arbol([2,2,4,4], True)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Building-up / Cutting-down

# %%
from Constructivo_Destructivo import *

# %%
g=Grafo([1,2,3,4])

for i in g.vertices:
    for j in g.vertices:
        if i > j:
            g.añadir_arista(i,j)
            
g.añadir_arista(1,5)
g.añadir_arista(2,5)

g.dibujar('circo')

# %%
Constructivo(g, True)
# Out:
# A Jupyter Widget

# %%
Constructivo(g).dibujar('circo')

# %%
Destructivo(g, True)
# Out:
# A Jupyter Widget

# %%
Destructivo(g).dibujar('circo')

# %% [markdown]
# ## Kruskal

# %%
from Kruskal_Constructivo_Destructivo import *

# %%
g=Grafo([1,2,3,4])

for i in g.vertices:
    for j in g.vertices:
        if i > j:
            g.añadir_arista(i,j)
            
g.añadir_arista(1,5)
g.añadir_arista(2,5)


g.ponderado([1,4,7,1,8,9,2,8])
g.dibujar_ponderado('circo')

# %%
Kruskal_Constructivo(g).dibujar_ponderado()

# %%
Kruskal_Constructivo(g,True)
# Out:
# A Jupyter Widget

# %%
Kruskal_Destructivo(g).dibujar_ponderado()

# %%
Kruskal_Destructivo(g,True)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Prim

# %%
from Prim import *

# %%
g=Grafo([1,2,3,4])

for i in g.vertices:
    for j in g.vertices:
        if i > j:
            g.añadir_arista(i,j)
            
g.añadir_arista(1,5)
g.añadir_arista(2,5)


g.ponderado([1,4,7,9,8,1,2,1])
g.dibujar_ponderado('circo')

# Intercambiamos los pesos de las aristas (1,4) y (4,3) para observar el comportamiento del algoritmo.

# %%
Prim(g).dibujar_ponderado()

# %%
Prim(g, True)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Boruvka

# %%
from Boruvka import *

# %%
g=Grafo([1,2,3,4])

for i in g.vertices:
    for j in g.vertices:
        if i > j:
            g.añadir_arista(i,j)
            
g.añadir_arista(1,5)
g.añadir_arista(2,5)


g.ponderado([1,4,7,9,8,1,2,8])
g.dibujar_ponderado('circo')

# %%
Boruvka(g).dibujar_ponderado()

# %%
Boruvka(g,True)
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Dijkstra

# %%
from Dijkstra import *

# %%
g=Grafo([],[(1,2), (2,3), (3,4), (4,1)])
g.ponderado([2,1,3,1])
g.dibujar_ponderado('circo')

# %%
Dijkstra(g,1)
# Out:
# m=  [0, 2, inf, 1]
# m=  [0, 2, 4, 1]
# m=  [0, 2, 3, 1]
# {'Pesos': [0, 2, 3, 1], 'Ruta': [1, 1, 2, 1]}

# %%
# Por simplicidad para el algoritmo hemos tomado el vector incial con todos sus elementos infinito salvo el del vértice inicial

Dijkstra(g,1,True)
# Out:
# A Jupyter Widget

# %% [markdown]
# Veamos qué ocurre si cambiamos el peso de la arista (3,4) por -3

# %%
g=Grafo([],[(1,2), (2,3), (3,4), (4,1)])
g.ponderado([2,1,-3,1])
g.dibujar_ponderado('circo')

# %%
Dijkstra(g,1)
# Out:
# m=  [0, 2, inf, 1]
# m=  [0, 2, -2, 1]
# m=  [0, -1, -2, 1]
# {'Pesos': [0, -1, -2, 1], 'Ruta': [1, 3, 4, 1]}

# %% [markdown]
# Como el algoritmo de Dijkstra no detecta los ciclos negativos, hemos incluido otros dos: **Bellman-Ford** y **Floyd-Warshall**

# %%
from Bellman_Ford import *

# %%
Bellman_Ford(g,1)
# Out:
# [0, 2, inf, 1]
# [0, 2, -3, 0]
# [-5, -2, -9, -6]
# [-11, -8, -15, -12]
# Hay ciclo negativo
# [[-17, -14, -21, -18], [4, 3, 4, 3]]

# %%
from Floyd_Warshall import *

# %%
Floyd_Warshall(g)
# Out:
# Hay ciclos negativos, no se puede hallar el camino de peso mínimo.
# [[[0, -26, -21, -14],
#   [-26, 0, -19, -12],
#   [-21, -19, 0, -7],
#   [-14, -12, -7, 0]],
#  [[1, 4, 4, 3], [4, 2, 4, 3], [4, 4, 3, 4], [3, 3, 3, 4]]]

# %% [markdown]
# ## Ford-Fulkerson

# %%
from Ford_Fulkerson import *

# %%
g=Grafo([],[(1,2),(1,3),(1,4),(2,3),(3,4),(3,5),(4,5)])
g.ponderado([[10,10],[10,20],[10,0],[30,10],[10,15],\
[20,20],[10,10]])

g.dibujar_ponderado()

# %%
Ford_Fulkerson(g,1,5,True)
# Out:
# A Jupyter Widget
